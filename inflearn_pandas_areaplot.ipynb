# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
 df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

# %%
df
# Out:
#           a         b         c         d
# 0  0.073534  0.639980  0.588468  0.009622
# 1  0.029194  0.505685  0.067559  0.468770
# 2  0.385846  0.791699  0.211452  0.278278
# 3  0.490542  0.261809  0.338589  0.433749
# 4  0.044280  0.727466  0.055356  0.030643
# 5  0.858967  0.245313  0.204677  0.792926
# 6  0.597166  0.289910  0.271294  0.816389
# 7  0.810931  0.685398  0.548624  0.423937
# 8  0.459126  0.282459  0.026632  0.006281
# 9  0.210695  0.510106  0.557273  0.774503

# %%
df.head()
# Out:
#           a         b         c         d
# 0  0.073534  0.639980  0.588468  0.009622
# 1  0.029194  0.505685  0.067559  0.468770
# 2  0.385846  0.791699  0.211452  0.278278
# 3  0.490542  0.261809  0.338589  0.433749
# 4  0.044280  0.727466  0.055356  0.030643

# %%
df.plot()

# %%
df.plot.area()
# NaN 값이 있으면 기본적으로 0으로 채웁니다.
# 값 누적이 기본 옵션입니다.

# %%
df.plot.area(stacked=False)
# stacked = True 가 기본옵션입니다.

# %%
df.plot.area(grid = True)
