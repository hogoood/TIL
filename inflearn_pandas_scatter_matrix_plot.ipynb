# %% [markdown]
# # Scatter Matrix Plot
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html#visualization

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
 from pandas.plotting import scatter_matrix

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])

# %%
df
# Out:
#             a         b         c         d
# 0    0.951793 -1.769244 -0.912362 -0.769550
# 1    0.935473  0.760644 -1.995261 -1.386559
# 2   -0.895883  0.773492 -0.540753 -2.739597
# 3    0.117894 -0.967567  0.969854  0.087780
# 4   -1.312144 -0.167859 -0.856655  1.471460
# ..        ...       ...       ...       ...
# 995 -0.373264 -0.850563 -1.194015  0.071148
# 996  0.570132  2.354868  0.708052 -1.430964
# 997 -1.125655  0.422635 -1.754677 -0.541120
# 998 -0.431396 -0.348408 -0.329534  1.446299
# 999 -0.879638 -0.505791 -0.585256 -1.130696
#
# [1000 rows x 4 columns]

# %%
df.head()
# Out:
#           a         b         c         d
# 0  0.951793 -1.769244 -0.912362 -0.769550
# 1  0.935473  0.760644 -1.995261 -1.386559
# 2 -0.895883  0.773492 -0.540753 -2.739597
# 3  0.117894 -0.967567  0.969854  0.087780
# 4 -1.312144 -0.167859 -0.856655  1.471460

# %%
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
# kde는 커널 밀도함수를 의미합니다.
# kde - kernel density estimate
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B78A633B08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B78B1DCAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B78B219A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B78B252B88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B78B28BC08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B78B2C2D08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B78B2FAE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B78B332F48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B78B33DB48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B78B375D08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B78B3DF248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B78B416348>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B78B44E488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B78B487588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B78B4C4E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B78B4F8788>]],
#       dtype=object)
