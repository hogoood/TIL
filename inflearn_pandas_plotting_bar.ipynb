# %%
import pandas as pd
import numpy as np

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame()

# %%
df.plot?

# %% [markdown]
# ## Plot
# ### kind : str
#     The kind of plot to produce:
#
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
#     - 'kde' : Kernel Density Estimation plot
#     - 'density' : same as 'kde'
#     - 'area' : area plot
#     - 'pie' : pie plot
#     - 'scatter' : scatter plot
#     - 'hexbin' : hexbin plot.

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2000', periods=1000))

# %%
ts
# Out:
# 2000-01-01    0.303610
# 2000-01-02    0.996894
# 2000-01-03   -1.521894
# 2000-01-04   -0.636604
# 2000-01-05    0.312144
#                 ...
# 2002-09-22    1.143049
# 2002-09-23   -1.116120
# 2002-09-24   -0.696616
# 2002-09-25    1.529836
# 2002-09-26   -0.678839
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4),
                  index=ts.index, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2000-01-01 -1.209218 -1.190856  0.501307  2.590713
# 2000-01-02 -0.606175 -0.817780  0.614125 -0.399017
# 2000-01-03 -1.460559 -0.487254 -0.917517  0.453494
# 2000-01-04  0.142903 -0.415161  0.739090 -0.333719
# 2000-01-05  0.424392 -0.535633 -1.562350  1.098074
# ...              ...       ...       ...       ...
# 2002-09-22 -1.570733 -0.350082  1.899154  0.391835
# 2002-09-23  0.685017  0.237065  1.949367  0.006383
# 2002-09-24 -2.345577  0.555501 -1.397862 -0.907836
# 2002-09-25  0.257520 -1.479242 -1.196947 -0.019438
# 2002-09-26  0.101669 -0.610246 -0.667867 -0.449426
#
# [1000 rows x 4 columns]

# %%
df.shape
# Out:
# (1000, 4)

# %%
df.plot()

# %%
df = df.cumsum()

# %%
df.plot()

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()

# %%
df3.head()
# Out:
#           B         C
# 0 -0.925870 -0.868384
# 1 -1.758008 -0.739231
# 2 -1.579189 -0.284775
# 3 -0.121696  0.093106
# 4 -1.705158  0.894235

# %%
df3.shape
# Out:
# (1000, 2)

# %%
df3['A'] = pd.Series(list(range(len(df))))

# %%
df3.head()
# Out:
#           B         C  A
# 0 -0.925870 -0.868384  0
# 1 -1.758008 -0.739231  1
# 2 -1.579189 -0.284775  2
# 3 -0.121696  0.093106  3
# 4 -1.705158  0.894235  4

# %%
df3.plot(x = 'A', y = 'B')

# %%
ts
# Out:
# 2000-01-01    0.531271
# 2000-01-02    0.648724
# 2000-01-03    1.307160
# 2000-01-04    0.328036
# 2000-01-05   -0.008346
#                 ...
# 2002-09-22   -0.331424
# 2002-09-23    0.878084
# 2002-09-24   -2.129555
# 2002-09-25   -0.126558
# 2002-09-26   -1.990747
# Freq: D, Length: 1000, dtype: float64

# %%
df
# Out:
#                    A         B         C         D
# 2000-01-01 -2.507737 -0.778961 -1.620701  0.378982
# 2000-01-02 -0.187015 -0.157520  0.497960 -1.711178
# 2000-01-03 -0.509273  1.055424 -0.408387  0.399189
# 2000-01-04 -0.549047 -0.042596  0.862696 -2.233836
# 2000-01-05 -0.171702  1.305758  0.103831  1.313161
# ...              ...       ...       ...       ...
# 2002-09-22 -0.105336 -2.672842  1.609921  0.178423
# 2002-09-23  0.655522  0.345793 -0.543281 -1.543481
# 2002-09-24  0.848216  1.595922 -0.833669  1.257712
# 2002-09-25  0.693150 -0.216520  0.518933  0.968565
# 2002-09-26  1.693585 -1.619944  0.617009 -1.681928
#
# [1000 rows x 4 columns]

# %%
df.iloc[5]
# Out:
# A   -0.245324
# B   -0.894389
# C   -1.135344
# D   -1.341769
# Name: 2000-01-06 00:00:00, dtype: float64

# %%
df.iloc[5].plot(kind = 'bar')

# %%
df.iloc[5].plot.bar()
plt.axhline(-0.8, color = 'k')

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

# %%
df2.head(3)
# Out:
#           a         b         c         d
# 0  0.393447  0.531558  0.954740  0.155417
# 1  0.236556  0.766884  0.327536  0.056818
# 2  0.903335  0.300579  0.607978  0.882111

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked = True)

# %%
df2.plot.barh(stacked = True)
